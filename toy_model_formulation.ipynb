# %% [markdown]
# ## Introduction

# %% [markdown]
# 1. We create N regularly spaced points (beads) on the [0,1] interval.
# - Their labels are alternating between +1 and -1.
#
# - To simplify the problem we assume that N is even.
#
# 2. We "thread the beads":
# - The feature map is created. The feature map takes the beads locations and maps them on one qubit.
#     The feature map consists of Hadamard layer, followed by a parameterized Z-rotation, followed by Hadamard layer.
#
#     First Hadamard layer, moves the initial state |0> to a |+> state, which resides on the bloch sphere equator.
#
#     The parameterized Z-rotation moves the beads around the equator. The rotation angle is defined as: (location of the bead)*(phi), where phi is the customizable parameter.
#
#     Second Hadamard layer transformes the states into the computational basis.
#
# - The ideal feature map will send all the +1 class beads to one (ex. |0>) pole of the bloch sphere and all the -1 class beads to the other pole.
#
#     In the ideal feature map each positive class bead is rotated to |+> (|->) state, while the negative class beads are rotated to |-> (|+>) states.
#
#     To achieve that the ideal map parameter value would be phi_ideal = (N-1)*np.pi (and its odd multiplicities).
#
# 3. We optimize the map parameter with respect to target kernel alignment and see whether we obtain the ideal feature map.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
#from pennylane 
import numpy as np
import matplotlib.pyplot as plt

import copy

from qiskit import Aer
from qiskit.algorithms.optimizers import SPSA

from qiskit import QuantumCircuit, assemble
from qiskit.visualization import plot_bloch_multivector, plot_histogram
from qiskit.circuit import Parameter

from matplotlib.colors import ListedColormap

plt.rcParams['figure.dpi'] = 200
plt.rcParams['figure.figsize'] = [10,5]
plt.rcParams['font.size'] = 20

# %% [markdown]
# ## Setup

# %% [markdown]
# Creating the beads

# %%
N = 10
x = np.linspace(0,1,N)
y = (-1)**np.linspace(0,N-1,N)

# %% [markdown]
# Defining the prototype of the feature map

# %%
sim = Aer.get_backend('aer_simulator')

# %%
def qubit_map(phi):
    qc = QuantumCircuit(1)
    qc.h(0)
    qc.p(phi, 0)
    qc.h(0)
    return(qc)

# %% [markdown]
# The map with the Pi rotation

# %%
qc1 = qubit_map(np.pi)
qc2 = qubit_map(-np.pi)
qc = qc1.compose(qc2)
qc.draw(output = 'mpl')

# %% [markdown]
# Sanity check for the prototype of the map

# %%
qc.save_statevector()
qobj = assemble(qc)
state = sim.run(qobj).result().get_statevector()
plot_bloch_multivector(state)

# %% [markdown]
# Define the kernel obtained from the feature map

# %%
def kernel_map():
    x1 = Parameter('x1')
    x2 = Parameter('x2')
    phi = Parameter('Φ')
    qc = QuantumCircuit(1,1)
    qc.h(0)
    qc.p(phi*x1, 0)
    qc.p(-1.0*phi*x2,0)
    qc.h(0)
    qc.measure(0, 0)
    return(x1, x2, phi, qc)

# %% [markdown]
# Function which calculates the kernel entries

# %%
def get_kernel_entry(qc, x1, x1_value, x2, x2_value, phi, phi_value, sim = Aer.get_backend('aer_simulator')): #, x1 = Parameter('x1'), x2 =  Parameter('x2'), phi = Parameter('Φ')
    qc_bound = qc.bind_parameters({x1:float(x1_value), x2:float(x2_value), phi:float(phi_value)})
    qobj = assemble(qc_bound)  # Assemble circuit into a Qobj that can be run
    counts = sim.run(qobj).result().get_counts()  # Do the simulation, returning the state vector
    if(counts.get('0')):
        kernel_element = counts.get('0')/(sum(counts[item] for item in counts))
    else:
        kernel_element = 0
    return(kernel_element)

# %%
x1, x2, phi, qc_test = kernel_map()

# %%
get_kernel_entry(qc= qc_test, x1= x1, x1_value=0, x2= x2, x2_value= 0.1, phi= phi, phi_value=1)
# Out:
# 0.9970703125

# %%
def get_kernel(x, phi_value):
    x1, x2, phi, qc_out = kernel_map()
    #return(qc_out.draw(output='mpl'))
    kernel = np.zeros((len(x),len(x)))
    for i in range(len(x)):
        for j in range(i):
            x1_value = x[i]
            x2_value = x[j]
            #print("x1: ", x1_value, "x2: ", x2_value)
            kernel[i,j] = get_kernel_entry(qc= qc_out, x1= x1, x1_value= x1_value, x2= x2, x2_value= x2_value, phi= phi, phi_value = phi_value)
    kernel = kernel+np.transpose(kernel) + np.identity(len(x))
    return(kernel)

# %%
get_kernel(x, np.pi)
# Out:
# array([[1.        , 0.96289062, 0.89941406, 0.7421875 , 0.58496094,
#         0.41308594, 0.25878906, 0.10546875, 0.02636719, 0.        ],
#        [0.96289062, 1.        , 0.97167969, 0.875     , 0.73730469,
#         0.58496094, 0.421875  , 0.24902344, 0.12792969, 0.03320312],
#        [0.89941406, 0.97167969, 1.        , 0.97851562, 0.87402344,
#         0.73632812, 0.58105469, 0.41113281, 0.23925781, 0.11816406],
#        [0.7421875 , 0.875     , 0.97851562, 1.        , 0.96191406,
#         0.87207031, 0.73242188, 0.578125  , 0.41796875, 0.22070312],
#        [0.58496094, 0.73730469, 0.87402344, 0.96191406, 1.        ,
#         0.97460938, 0.90136719, 0.7421875 , 0.59472656, 0.40917969],
#        [0.41308594, 0.58496094, 0.73632812, 0.87207031, 0.97460938,
#         1.        , 0.97070312, 0.89160156, 0.73828125, 0.56445312],
#        [0.25878906, 0.421875  , 0.58105469, 0.73242188, 0.90136719,
#         0.97070312, 1.        , 0.96875   , 0.8828125 , 0.75195312],
#        [0.10546875, 0.24902344, 0.41113281, 0.578125  , 0.7421875 ,
#         0.89160156, 0.96875   , 1.        , 0.96972656, 0.89257812],
#        [0.02636719, 0.12792969, 0.23925781, 0.41796875, 0.59472656,
#         0.73828125, 0.8828125 , 0.96972656, 1.        , 0.96777344],
#        [0.        , 0.03320312, 0.11816406, 0.22070312, 0.40917969,
#         0.56445312, 0.75195312, 0.89257812, 0.96777344, 1.        ]])

# %% [markdown]
# Define taget kernel alignment

# %%
def matrix_target_alignment(K, Y, rescale_class_labels=True):
    if rescale_class_labels:
        nplus = np.count_nonzero(np.array(Y) == 1)
        nminus = len(Y) - nplus
        _Y = np.array([y / nplus if y == 1 else y / nminus for y in Y])
    else:
        _Y = np.array(Y)

    #####
    labels = _Y.copy()
    classes = np.unique(labels)
    centered_labels = (labels - classes.mean())
    _Y = centered_labels/centered_labels.max()
    #####

    T = np.outer(_Y, _Y)
    inner_product = np.sum(K * T)
    norm = np.sqrt(np.sum(K * K) * np.sum(T * T))
    inner_product = inner_product / norm

    return inner_product

# %%
matrix_target_alignment(get_kernel(x, np.pi), y) #TA for a phi = pi, it is a very non-special choice
# Out:
# 0.009531906439142528

# %%
matrix_target_alignment(get_kernel(x, (N-1)*np.pi), y) #TA for the best choice of the parameter
# Out:
# 0.7071067811865475

# %% [markdown]
# Single SPSA optimization run

# %%
def loss(phi_val):
    return( - matrix_target_alignment(get_kernel(x, phi_val), y))

# %% [markdown]
# Target kernel alignment landscape

# %%
startpoint = 0
endpoint = 2*np.pi*N
points_number = 200
param_test = np.linspace(startpoint,endpoint, points_number)

# %%
Target_a = []
for item in param_test:
    Target_a.append(-loss(item))

# %%
plt.plot(param_test, Target_a, c="k", marker="o")
plt.xlabel("phi")
plt.ylabel("TA")
plt.show()

# %%
class QKTCallback:
    """Callback wrapper class."""

    def __init__(self) -> None:
        self._data = [[] for i in range(5)]

    def callback(self, x0, x1=None, x2=None, x3=None, x4=None):
        """
        Args:
            x0: number of function evaluations
            x1: the parameters
            x2: the function value
            x3: the stepsize
            x4: whether the step was accepted
        """
        self._data[0].append(x0)
        self._data[1].append(x1)
        self._data[2].append(x2)
        self._data[3].append(x3)
        self._data[4].append(x4)

    def get_callback_data(self):
        return self._data

    def clear_callback_data(self):
        self._data = [[] for i in range(5)]

# %%
cb_qkt = QKTCallback()
initial_point = [0.85*np.pi*(N-1)]
spsa = SPSA(maxiter=20, callback=cb_qkt.callback, learning_rate=10.0, perturbation=1.0)
result = spsa.optimize(1, loss, initial_point=initial_point)
# Out:
# /tmp/ipykernel_6353/2661987733.py:4: DeprecationWarning: The SPSA.optimize method is deprecated as of Qiskit Terra 0.21.0 and will be removed no sooner than 3 months after the release date. Instead, use SPSA.minimize as a replacement, which supports the same arguments but follows the interface of scipy.optimize and returns a complete result object containing additional information.
#   result = spsa.optimize(1, loss, initial_point=initial_point)

# %%
callback = cb_qkt.get_callback_data()
TA = callback[2]
param = callback[1]

# %%
print("Starting parameter: ", initial_point[0], "\nEnd parameter: ", param[-1], "\nIdeal value: ", np.pi*N, "\nLoss: ", TA[-1] , "\nIdeal loss: ", loss(np.pi*N))
param[-1]
# Out:
# Starting parameter:  24.03318379996192
# End parameter:  [28.27240587]
# Ideal value:  31.41592653589793
# Loss:  -0.7071067811865475
# Ideal loss:  -0.25855387622468445
# array([28.27240587])

# %%
plt.plot(callback[0], TA, c="k", marker="o")
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.show()

# %%
plt.plot(callback[0], param, c="k", marker="o")
plt.xlabel("Iteration")
plt.ylabel("Parameter Value")
plt.show()

# %% [markdown]
# Many optimization runs

# %%
def replace_better_callback(cb_qkt_new, cb_qkt_old):
  if(cb_qkt_new[2][-1] < cb_qkt_old[2][-1]):
    #print('new callback is better!')
    return(cb_qkt_new)
  else:
    #print('old callback is better!')
    return(cb_qkt_old)

# %%
def run_optimizations(runs = 10, max_init=100, maxiter = 20, learning_rate = 10.0, perturbation = 1.0):
  for i in range(runs):
    initial_point = [max_init*np.random.rand()]
    spsa = SPSA(maxiter=maxiter, callback=cb_qkt.callback, learning_rate=learning_rate, perturbation=perturbation)
    result = spsa.optimize(1, loss, initial_point=initial_point)
    callback = cb_qkt.get_callback_data()
    if(i==0): best_callback = copy.deepcopy(callback)
    best_callback = copy.deepcopy(replace_better_callback(callback, best_callback))
    print('initial_point: ', initial_point)
    print('end loss: ', callback[2][-1])
    print('--------------------------------')
  print('Best loss: ', best_callback[2][-1])
  return(best_callback)

# %%
optimized_callback = run_optimizations(runs= 5)
# Out:
# initial_point:  [37.10125695318599]
# end loss:  -0.03879016264767424
# --------------------------------
# initial_point:  [8.89734770788081]
# end loss:  -0.00797742649691282
# --------------------------------
# initial_point:  [18.42144749141005]
# end loss:  -0.04381340714097959
# --------------------------------
# initial_point:  [36.72557373533573]
# end loss:  -0.04101027627088111
# --------------------------------
# initial_point:  [75.58158512489463]
# end loss:  -0.0416817373847636
# --------------------------------
# Best loss:  -0.04381340714097959

# %%
TA = optimized_callback[2]
param = optimized_callback[1]
print("Starting parameter: ", initial_point[0], "\nEnd parameter: ", param[-1], "\nIdeal value: ", np.pi*N, "\nLoss: ", TA[-1] , "\nIdeal loss: ", loss(np.pi*N))
# Out:
# Starting parameter:  24.03318379996192
# End parameter:  [28.2698692]
# Ideal value:  28.274333882308138
# Loss:  -0.7071067811865477
# Ideal loss:  -0.7071067811865477

# %% [markdown]
# Kernel characteristics

# %%
Kt = get_kernel(x, np.pi)

# %%
Kt = get_kernel(x, N*np.pi)
Kt
# Out:
# array([[1.        , 0.02441406, 0.88671875, 0.23242188, 0.58398438,
#         0.5859375 , 0.26269531, 0.88671875, 0.02832031, 1.        ],
#        [0.02441406, 1.        , 0.02636719, 0.85839844, 0.25878906,
#         0.60058594, 0.58007812, 0.25390625, 0.88867188, 0.015625  ],
#        [0.88671875, 0.02636719, 1.        , 0.02734375, 0.87304688,
#         0.24511719, 0.57617188, 0.59179688, 0.26171875, 0.87695312],
#        [0.23242188, 0.85839844, 0.02734375, 1.        , 0.04589844,
#         0.87207031, 0.25292969, 0.58398438, 0.58398438, 0.25292969],
#        [0.58398438, 0.25878906, 0.87304688, 0.04589844, 1.        ,
#         0.03320312, 0.88085938, 0.24316406, 0.59570312, 0.59472656],
#        [0.5859375 , 0.60058594, 0.24511719, 0.87207031, 0.03320312,
#         1.        , 0.03125   , 0.890625  , 0.26171875, 0.60253906],
#        [0.26269531, 0.58007812, 0.57617188, 0.25292969, 0.88085938,
#         0.03125   , 1.        , 0.0234375 , 0.87988281, 0.26855469],
#        [0.88671875, 0.25390625, 0.59179688, 0.58398438, 0.24316406,
#         0.890625  , 0.0234375 , 1.        , 0.02734375, 0.89453125],
#        [0.02832031, 0.88867188, 0.26171875, 0.58398438, 0.59570312,
#         0.26171875, 0.87988281, 0.02734375, 1.        , 0.03027344],
#        [1.        , 0.015625  , 0.87695312, 0.25292969, 0.59472656,
#         0.60253906, 0.26855469, 0.89453125, 0.03027344, 1.        ]])

# %%
def kernel_2_list(K):
  l = []
  n = K.shape[0]
  for i in range(n):
    for j in range(i):
      l.append(K[j,i])
  return(l)

# %%
plt.hist(kernel_2_list(Kt))
# Out:
# (array([11.,  0., 11.,  0.,  0., 11.,  0.,  0., 11.,  1.]),
#  array([0.015625 , 0.1140625, 0.2125   , 0.3109375, 0.409375 , 0.5078125,
#         0.60625  , 0.7046875, 0.803125 , 0.9015625, 1.       ]),
#  <BarContainer object of 10 artists>)
